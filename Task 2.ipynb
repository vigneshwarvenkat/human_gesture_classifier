# %% [markdown]
# # Task 2: Understand body language by gesture recognition with convolutional neural network

# %% [markdown]
# ## 1. Do literature search on Convolution Neural Network. Learn how to build a convolutional layer in PyTorch.

# %% [markdown]
# ## 2. Referring to the guide in Task 1, build your own network for gesture classification using convolutional layers. Please see the references 4 in the manual to learn how to build convolutional layers in PyTorch.

# %% [markdown]
# ## 3. Analyse and comment on the performance of the model. Make a comparison between the fully connected based and convolutional based models and comment on it.

# %%
import cv2
import numpy as np
import os
import itertools
import torch.utils.data as utils_data
import torch
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.nn import Flatten, LogSoftmax, Linear, ReLU, CrossEntropyLoss, Sequential, Conv1d, Conv2d, MaxPool2d, Module, Softmax, BatchNorm1d, BatchNorm2d, Dropout
from torch.optim import Adam, SGD

# %%
path = './dataset/dataset/images'
dataset = ImageFolder(path,transform = transforms.Compose([
    transforms.Resize((48,48)),transforms.ToTensor()
]))
print(dataset[0])
# Out:
# (tensor([[[0.8824, 0.8784, 0.8745,  ..., 0.6980, 0.7020, 0.6980],
#          [0.8784, 0.8784, 0.8706,  ..., 0.6980, 0.7020, 0.6941],
#          [0.8784, 0.8706, 0.8667,  ..., 0.6980, 0.6980, 0.6863],
#          ...,
#          [0.5686, 0.5765, 0.5804,  ..., 0.1922, 0.1922, 0.1922],
#          [0.5725, 0.5765, 0.5804,  ..., 0.1176, 0.1333, 0.1451],
#          [0.5765, 0.5765, 0.5765,  ..., 0.0902, 0.1059, 0.1294]],
#
#         [[0.9059, 0.9020, 0.8980,  ..., 0.7216, 0.7216, 0.7255],
#          [0.9020, 0.9020, 0.8941,  ..., 0.7176, 0.7176, 0.7176],
#          [0.8941, 0.8941, 0.8824,  ..., 0.7176, 0.7176, 0.7137],
#          ...,
#          [0.5804, 0.5804, 0.5843,  ..., 0.1333, 0.1294, 0.1294],
#          [0.5804, 0.5843, 0.5882,  ..., 0.0784, 0.0824, 0.0902],
#          [0.5843, 0.5882, 0.5843,  ..., 0.0588, 0.0627, 0.0824]],
#
#         [[0.9059, 0.9020, 0.8980,  ..., 0.7412, 0.7412, 0.7490],
#          [0.9020, 0.9020, 0.8941,  ..., 0.7451, 0.7451, 0.7451],
#          [0.8980, 0.8941, 0.8863,  ..., 0.7451, 0.7451, 0.7412],
#          ...,
#          [0.5529, 0.5490, 0.5529,  ..., 0.0980, 0.0863, 0.0863],
#          [0.5529, 0.5529, 0.5608,  ..., 0.0510, 0.0549, 0.0667],
#          [0.5529, 0.5529, 0.5569,  ..., 0.0471, 0.0510, 0.0667]]]), 0)

# %%
class CNNModel(Module):
    def __init__(self, num_classes):
        super(CNNModel, self).__init__()
        # code by yourself
        # first CONV => RELU => POOL combos
        self.conv1 = Conv2d(in_channels=3, out_channels=6,
        kernel_size=(3,3))
        self.relu1 = ReLU()
        self.maxpool1 = MaxPool2d(kernel_size=(2, 2), stride=2)
        # second CONV + RELU + POOL combos
        self.conv2 = Conv2d(in_channels=6, out_channels=12,
        kernel_size=(2,2))
        self.relu2 = ReLU()
        self.maxpool2 = MaxPool2d(kernel_size=(2, 2), stride=2)
        # initialize first (and only) set of FC => RELU layers
        self.fc1 = Linear(in_features=12*11*11, out_features=256)
        self.relu3 = ReLU()
        self.fc2 = Linear(in_features=256, out_features=num_classes)
        
    def forward(self, x):
        # pass the input through our first set of CONV => RELU =>
        # POOL layers
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.maxpool1(x)
        # pass the output from the previous layer through the second
        # set of CONV => RELU => POOL layers
        x = self.conv2(x)
        x = self.relu2(x)
        x = self.maxpool2(x)
        # flatten the output from the previous layer and pass it
        # through our only set of FC => RELU layers
        x = x.view(-1,12*11*11)
        x = self.fc1(x)
        x = self.relu3(x)
        # pass the output to our softmax classifier to get our output
        # predictions
        output = self.fc2(x)
        # return the output predictions
        return output

# %%
model = CNNModel(num_classes=4)
# if torch.cuda.is_available():
#     model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
loss_func = CrossEntropyLoss()

# %%
#dataset = utils_data.TensorDataset(torch.Tensor(Image), torch.LongTensor(Label))
dataset_size = len(dataset)
split_ratio = 0.8
train_size = int(split_ratio * dataset_size)
test_size = dataset_size - train_size
train_set, test_set = utils_data.random_split(dataset, [train_size, test_size])
train_loader = utils_data.DataLoader(dataset=train_set, batch_size=8, shuffle=True)
test_loader = utils_data.DataLoader(dataset=test_set, batch_size=8, shuffle=True)
print('Data is ready!')
# Out:
# Data is ready!

# %%
best_accuracy = 0
for epoch in range(200):
    running_loss = 0.0
    train_acc = 0.0
    for step, (batch_image, batch_label) in enumerate(train_loader):
        model.train()
        # if torch.cuda.is_available():
        #     batch_image, batch_label = batch_image.cuda(), batch_label.cuda()
        batch_output = model(batch_image)
        batch_loss = loss_func(batch_output, batch_label)

        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()

        running_loss += batch_loss.item()

        # train accuracy
        _, train_predicted = torch.max(batch_output.data, 1)
        train_acc += (train_predicted == batch_label).sum().item()

    train_acc /= train_size
    running_loss /= (step+1)

    # ----------test----------
    model.eval()
    test_acc = 0.0
    for test_image, test_label in test_loader:
        test_output = model(test_image)
        _, predicted = torch.max(test_output.data, 1)
        test_acc += (predicted == test_label).sum().item()
    test_acc /= test_size

    print('epoch={:d}\ttrain loss={:.6f}\ttrain accuracy={:.3f}\ttest accuracy={:.3f}'.format(
        epoch, running_loss, train_acc, test_acc))

    if test_acc >= best_accuracy:
        torch.save(model.state_dict(), './trained_models/CNN_model.pkl')
        best_accuracy = test_acc
# Out:
# epoch=0	train loss=1.412903	train accuracy=0.242	test accuracy=0.438
# epoch=1	train loss=1.315163	train accuracy=0.323	test accuracy=0.500
# epoch=2	train loss=1.236782	train accuracy=0.581	test accuracy=0.750
# epoch=3	train loss=1.097561	train accuracy=0.613	test accuracy=0.875
# epoch=4	train loss=0.846880	train accuracy=0.871	test accuracy=1.000
# epoch=5	train loss=0.555218	train accuracy=0.935	test accuracy=1.000
# epoch=6	train loss=0.253123	train accuracy=1.000	test accuracy=1.000
# epoch=7	train loss=0.093640	train accuracy=1.000	test accuracy=1.000
# epoch=8	train loss=0.069171	train accuracy=0.984	test accuracy=1.000
# epoch=9	train loss=0.047306	train accuracy=0.984	test accuracy=1.000
# epoch=10	train loss=0.042384	train accuracy=0.984	test accuracy=1.000
# epoch=11	train loss=0.066286	train accuracy=0.984	test accuracy=1.000
# epoch=12	train loss=0.095662	train accuracy=0.968	test accuracy=1.000
# epoch=13	train loss=0.038272	train accuracy=0.984	test accuracy=1.000
# epoch=14	train loss=0.006533	train accuracy=1.000	test accuracy=1.000
# epoch=15	train loss=0.012223	train accuracy=1.000	test accuracy=1.000
# epoch=16	train loss=0.005710	train accuracy=1.000	test accuracy=1.000
# epoch=17	train loss=0.004937	train accuracy=1.000	test accuracy=1.000
# epoch=18	train loss=0.004260	train accuracy=1.000	test accuracy=1.000
# epoch=19	train loss=0.003049	train accuracy=1.000	test accuracy=1.000
# epoch=20	train loss=0.002549	train accuracy=1.000	test accuracy=1.000
# epoch=21	train loss=0.002173	train accuracy=1.000	test accuracy=1.000
# epoch=22	train loss=0.002104	train accuracy=1.000	test accuracy=1.000
# epoch=23	train loss=0.002293	train accuracy=1.000	test accuracy=1.000
# epoch=24	train loss=0.001903	train accuracy=1.000	test accuracy=1.000
# epoch=25	train loss=0.001792	train accuracy=1.000	test accuracy=1.000
# epoch=26	train loss=0.001777	train accuracy=1.000	test accuracy=1.000
# epoch=27	train loss=0.001627	train accuracy=1.000	test accuracy=1.000
# epoch=28	train loss=0.001636	train accuracy=1.000	test accuracy=1.000
# epoch=29	train loss=0.001395	train accuracy=1.000	test accuracy=1.000
# epoch=30	train loss=0.001436	train accuracy=1.000	test accuracy=1.000
# epoch=31	train loss=0.001320	train accuracy=1.000	test accuracy=1.000
# epoch=32	train loss=0.001297	train accuracy=1.000	test accuracy=1.000
# epoch=33	train loss=0.001175	train accuracy=1.000	test accuracy=1.000
# epoch=34	train loss=0.001122	train accuracy=1.000	test accuracy=1.000
# epoch=35	train loss=0.001101	train accuracy=1.000	test accuracy=1.000
# epoch=36	train loss=0.001049	train accuracy=1.000	test accuracy=1.000
# epoch=37	train loss=0.000954	train accuracy=1.000	test accuracy=1.000
# epoch=38	train loss=0.000954	train accuracy=1.000	test accuracy=1.000
# epoch=39	train loss=0.000904	train accuracy=1.000	test accuracy=1.000
# epoch=40	train loss=0.000949	train accuracy=1.000	test accuracy=1.000
# epoch=41	train loss=0.000854	train accuracy=1.000	test accuracy=1.000
# epoch=42	train loss=0.000946	train accuracy=1.000	test accuracy=1.000
# epoch=43	train loss=0.000789	train accuracy=1.000	test accuracy=1.000
# epoch=44	train loss=0.000772	train accuracy=1.000	test accuracy=1.000
# epoch=45	train loss=0.000812	train accuracy=1.000	test accuracy=1.000
# epoch=46	train loss=0.000742	train accuracy=1.000	test accuracy=1.000
# epoch=47	train loss=0.000697	train accuracy=1.000	test accuracy=1.000
# epoch=48	train loss=0.000688	train accuracy=1.000	test accuracy=1.000
# epoch=49	train loss=0.000681	train accuracy=1.000	test accuracy=1.000
# epoch=50	train loss=0.000646	train accuracy=1.000	test accuracy=1.000
# epoch=51	train loss=0.000779	train accuracy=1.000	test accuracy=1.000
# epoch=52	train loss=0.000717	train accuracy=1.000	test accuracy=1.000
# epoch=53	train loss=0.000627	train accuracy=1.000	test accuracy=1.000
# epoch=54	train loss=0.000680	train accuracy=1.000	test accuracy=1.000
# epoch=55	train loss=0.000548	train accuracy=1.000	test accuracy=1.000
# epoch=56	train loss=0.000561	train accuracy=1.000	test accuracy=1.000
# epoch=57	train loss=0.000533	train accuracy=1.000	test accuracy=1.000
# epoch=58	train loss=0.000536	train accuracy=1.000	test accuracy=1.000
# epoch=59	train loss=0.000616	train accuracy=1.000	test accuracy=1.000
# epoch=60	train loss=0.000525	train accuracy=1.000	test accuracy=1.000
# epoch=61	train loss=0.000481	train accuracy=1.000	test accuracy=1.000
# epoch=62	train loss=0.000486	train accuracy=1.000	test accuracy=1.000
# epoch=63	train loss=0.000475	train accuracy=1.000	test accuracy=1.000
# epoch=64	train loss=0.000485	train accuracy=1.000	test accuracy=1.000
# epoch=65	train loss=0.000455	train accuracy=1.000	test accuracy=1.000
# epoch=66	train loss=0.000419	train accuracy=1.000	test accuracy=1.000
# epoch=67	train loss=0.000431	train accuracy=1.000	test accuracy=1.000
# epoch=68	train loss=0.000403	train accuracy=1.000	test accuracy=1.000
# epoch=69	train loss=0.000401	train accuracy=1.000	test accuracy=1.000
# epoch=70	train loss=0.000403	train accuracy=1.000	test accuracy=1.000
# epoch=71	train loss=0.000404	train accuracy=1.000	test accuracy=1.000
# epoch=72	train loss=0.000460	train accuracy=1.000	test accuracy=1.000
# epoch=73	train loss=0.000371	train accuracy=1.000	test accuracy=1.000
# epoch=74	train loss=0.000430	train accuracy=1.000	test accuracy=1.000
# epoch=75	train loss=0.000357	train accuracy=1.000	test accuracy=1.000
# epoch=76	train loss=0.000351	train accuracy=1.000	test accuracy=1.000
# epoch=77	train loss=0.000396	train accuracy=1.000	test accuracy=1.000
# epoch=78	train loss=0.000354	train accuracy=1.000	test accuracy=1.000
# epoch=79	train loss=0.000339	train accuracy=1.000	test accuracy=1.000
# epoch=80	train loss=0.000333	train accuracy=1.000	test accuracy=1.000
# epoch=81	train loss=0.000355	train accuracy=1.000	test accuracy=1.000
# epoch=82	train loss=0.000323	train accuracy=1.000	test accuracy=1.000
# epoch=83	train loss=0.000311	train accuracy=1.000	test accuracy=1.000
# epoch=84	train loss=0.000312	train accuracy=1.000	test accuracy=1.000
# epoch=85	train loss=0.000320	train accuracy=1.000	test accuracy=1.000
# epoch=86	train loss=0.000314	train accuracy=1.000	test accuracy=1.000
# epoch=87	train loss=0.000302	train accuracy=1.000	test accuracy=1.000
# epoch=88	train loss=0.000305	train accuracy=1.000	test accuracy=1.000
# epoch=89	train loss=0.000282	train accuracy=1.000	test accuracy=1.000
# epoch=90	train loss=0.000295	train accuracy=1.000	test accuracy=1.000
# epoch=91	train loss=0.000312	train accuracy=1.000	test accuracy=1.000
# epoch=92	train loss=0.000288	train accuracy=1.000	test accuracy=1.000
# epoch=93	train loss=0.000310	train accuracy=1.000	test accuracy=1.000
# epoch=94	train loss=0.000259	train accuracy=1.000	test accuracy=1.000
# epoch=95	train loss=0.000269	train accuracy=1.000	test accuracy=1.000
# epoch=96	train loss=0.000268	train accuracy=1.000	test accuracy=1.000
# epoch=97	train loss=0.000266	train accuracy=1.000	test accuracy=1.000
# epoch=98	train loss=0.000254	train accuracy=1.000	test accuracy=1.000
# epoch=99	train loss=0.000249	train accuracy=1.000	test accuracy=1.000
# epoch=100	train loss=0.000252	train accuracy=1.000	test accuracy=1.000
# epoch=101	train loss=0.000240	train accuracy=1.000	test accuracy=1.000
# epoch=102	train loss=0.000247	train accuracy=1.000	test accuracy=1.000
# epoch=103	train loss=0.000271	train accuracy=1.000	test accuracy=1.000
# epoch=104	train loss=0.000242	train accuracy=1.000	test accuracy=1.000
# epoch=105	train loss=0.000258	train accuracy=1.000	test accuracy=1.000
# epoch=106	train loss=0.000227	train accuracy=1.000	test accuracy=1.000
# epoch=107	train loss=0.000292	train accuracy=1.000	test accuracy=1.000
# epoch=108	train loss=0.000252	train accuracy=1.000	test accuracy=1.000
# epoch=109	train loss=0.000225	train accuracy=1.000	test accuracy=1.000
# epoch=110	train loss=0.000211	train accuracy=1.000	test accuracy=1.000
# epoch=111	train loss=0.000219	train accuracy=1.000	test accuracy=1.000
# epoch=112	train loss=0.000212	train accuracy=1.000	test accuracy=1.000
# epoch=113	train loss=0.000208	train accuracy=1.000	test accuracy=1.000
# epoch=114	train loss=0.000206	train accuracy=1.000	test accuracy=1.000
# epoch=115	train loss=0.000243	train accuracy=1.000	test accuracy=1.000
# epoch=116	train loss=0.000208	train accuracy=1.000	test accuracy=1.000
# epoch=117	train loss=0.000220	train accuracy=1.000	test accuracy=1.000
# epoch=118	train loss=0.000196	train accuracy=1.000	test accuracy=1.000
# epoch=119	train loss=0.000203	train accuracy=1.000	test accuracy=1.000
# epoch=120	train loss=0.000215	train accuracy=1.000	test accuracy=1.000
# epoch=121	train loss=0.000209	train accuracy=1.000	test accuracy=1.000
# epoch=122	train loss=0.000207	train accuracy=1.000	test accuracy=1.000
# epoch=123	train loss=0.000191	train accuracy=1.000	test accuracy=1.000
# epoch=124	train loss=0.000184	train accuracy=1.000	test accuracy=1.000
# epoch=125	train loss=0.000205	train accuracy=1.000	test accuracy=1.000
# epoch=126	train loss=0.000182	train accuracy=1.000	test accuracy=1.000
# epoch=127	train loss=0.000188	train accuracy=1.000	test accuracy=1.000
# epoch=128	train loss=0.000193	train accuracy=1.000	test accuracy=1.000
# epoch=129	train loss=0.000179	train accuracy=1.000	test accuracy=1.000
# epoch=130	train loss=0.000179	train accuracy=1.000	test accuracy=1.000
# epoch=131	train loss=0.000179	train accuracy=1.000	test accuracy=1.000
# epoch=132	train loss=0.000196	train accuracy=1.000	test accuracy=1.000
# epoch=133	train loss=0.000169	train accuracy=1.000	test accuracy=1.000
# epoch=134	train loss=0.000168	train accuracy=1.000	test accuracy=1.000
# epoch=135	train loss=0.000167	train accuracy=1.000	test accuracy=1.000
# epoch=136	train loss=0.000186	train accuracy=1.000	test accuracy=1.000
# epoch=137	train loss=0.000169	train accuracy=1.000	test accuracy=1.000
# epoch=138	train loss=0.000167	train accuracy=1.000	test accuracy=1.000
# epoch=139	train loss=0.000189	train accuracy=1.000	test accuracy=1.000
# epoch=140	train loss=0.000167	train accuracy=1.000	test accuracy=1.000
# epoch=141	train loss=0.000169	train accuracy=1.000	test accuracy=1.000
# epoch=142	train loss=0.000162	train accuracy=1.000	test accuracy=1.000
# epoch=143	train loss=0.000160	train accuracy=1.000	test accuracy=1.000
# epoch=144	train loss=0.000162	train accuracy=1.000	test accuracy=1.000
# epoch=145	train loss=0.000156	train accuracy=1.000	test accuracy=1.000
# epoch=146	train loss=0.000156	train accuracy=1.000	test accuracy=1.000
# epoch=147	train loss=0.000155	train accuracy=1.000	test accuracy=1.000
# epoch=148	train loss=0.000150	train accuracy=1.000	test accuracy=1.000
# epoch=149	train loss=0.000163	train accuracy=1.000	test accuracy=1.000
# epoch=150	train loss=0.000153	train accuracy=1.000	test accuracy=1.000
# epoch=151	train loss=0.000151	train accuracy=1.000	test accuracy=1.000
# epoch=152	train loss=0.000169	train accuracy=1.000	test accuracy=1.000
# epoch=153	train loss=0.000156	train accuracy=1.000	test accuracy=1.000
# epoch=154	train loss=0.000162	train accuracy=1.000	test accuracy=1.000
# epoch=155	train loss=0.000145	train accuracy=1.000	test accuracy=1.000
# epoch=156	train loss=0.000146	train accuracy=1.000	test accuracy=1.000
# epoch=157	train loss=0.000166	train accuracy=1.000	test accuracy=1.000
# epoch=158	train loss=0.000142	train accuracy=1.000	test accuracy=1.000
# epoch=159	train loss=0.000145	train accuracy=1.000	test accuracy=1.000
# epoch=160	train loss=0.000147	train accuracy=1.000	test accuracy=1.000
# epoch=161	train loss=0.000141	train accuracy=1.000	test accuracy=1.000
# epoch=162	train loss=0.000146	train accuracy=1.000	test accuracy=1.000
# epoch=163	train loss=0.000145	train accuracy=1.000	test accuracy=1.000
# epoch=164	train loss=0.000137	train accuracy=1.000	test accuracy=1.000
# epoch=165	train loss=0.000147	train accuracy=1.000	test accuracy=1.000
# epoch=166	train loss=0.000137	train accuracy=1.000	test accuracy=1.000
# epoch=167	train loss=0.000137	train accuracy=1.000	test accuracy=1.000
# epoch=168	train loss=0.000136	train accuracy=1.000	test accuracy=1.000
# epoch=169	train loss=0.000151	train accuracy=1.000	test accuracy=1.000
# epoch=170	train loss=0.000166	train accuracy=1.000	test accuracy=1.000
# epoch=171	train loss=0.000143	train accuracy=1.000	test accuracy=1.000
# epoch=172	train loss=0.000136	train accuracy=1.000	test accuracy=1.000
# epoch=173	train loss=0.000131	train accuracy=1.000	test accuracy=1.000
# epoch=174	train loss=0.000131	train accuracy=1.000	test accuracy=1.000
# epoch=175	train loss=0.000138	train accuracy=1.000	test accuracy=1.000
# epoch=176	train loss=0.000136	train accuracy=1.000	test accuracy=1.000
# epoch=177	train loss=0.000133	train accuracy=1.000	test accuracy=1.000
# epoch=178	train loss=0.000127	train accuracy=1.000	test accuracy=1.000
# epoch=179	train loss=0.000133	train accuracy=1.000	test accuracy=1.000
# epoch=180	train loss=0.000122	train accuracy=1.000	test accuracy=1.000
# epoch=181	train loss=0.000130	train accuracy=1.000	test accuracy=1.000
# epoch=182	train loss=0.000123	train accuracy=1.000	test accuracy=1.000
# epoch=183	train loss=0.000127	train accuracy=1.000	test accuracy=1.000
# epoch=184	train loss=0.000126	train accuracy=1.000	test accuracy=1.000
# epoch=185	train loss=0.000122	train accuracy=1.000	test accuracy=1.000
# epoch=186	train loss=0.000122	train accuracy=1.000	test accuracy=1.000
# epoch=187	train loss=0.000120	train accuracy=1.000	test accuracy=1.000
# epoch=188	train loss=0.000125	train accuracy=1.000	test accuracy=1.000
# epoch=189	train loss=0.000121	train accuracy=1.000	test accuracy=1.000
# epoch=190	train loss=0.000127	train accuracy=1.000	test accuracy=1.000
# epoch=191	train loss=0.000118	train accuracy=1.000	test accuracy=1.000
# epoch=192	train loss=0.000132	train accuracy=1.000	test accuracy=1.000
# epoch=193	train loss=0.000116	train accuracy=1.000	test accuracy=1.000
# epoch=194	train loss=0.000117	train accuracy=1.000	test accuracy=1.000
# epoch=195	train loss=0.000117	train accuracy=1.000	test accuracy=1.000
# epoch=196	train loss=0.000127	train accuracy=1.000	test accuracy=1.000
# epoch=197	train loss=0.000114	train accuracy=1.000	test accuracy=1.000
# epoch=198	train loss=0.000131	train accuracy=1.000	test accuracy=1.000
# epoch=199	train loss=0.000114	train accuracy=1.000	test accuracy=1.000
